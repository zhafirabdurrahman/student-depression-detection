# %% [markdown]
# # Model Inference

# %%
# Import Libraries
import pickle
import pandas as pd
from transformer import CityToRegionTransformer, DropColumnsTransformer, DegreeMappingTransformer

# %%
# Load the best svm model
with open('model_svm.pkl', 'rb') as model_file:
    loaded_model = pickle.load(model_file)

# %%
# Membuat DataFrame untuk dua user baru
data_inf = {
    'id': [0,1],
    'Gender': ['Male','Female'],
    'Age': [25,24],
    'City': ['Bandung','Bangalore'],
    'Profession': ['Student','Student'],
    'Academic Pressure': [5.0,2.0],
    'Work Pressure': [5.0,2.0],
    'CGPA': [9.0, 5.9],
    'Study Satisfaction': [2.0, 4.0],
    'Job Satisfaction': [0,0],
    'Sleep Duration': ['7-8 Hours', '5-6 hours'],
    'Dietary Habits': ['Healthy', 'Moderate'],
    'Degree': ['BSc', 'Class 12'],
    'Suicidal Thoughts': ['Yes','No'],
    'Work/Study Hours': [3.0, 3.0],
    'Financial Stress': [1.0, 2.0],
    'Family History of Mental Illness': ['Yes', 'No']
}

df_users = pd.DataFrame(data_inf, index=['User 1', 'User 2'])
df_users
# Out:
#         id  Gender  Age       City Profession  Academic Pressure  \
# User 1   0    Male   25    Bandung    Student                5.0
# User 2   1  Female   24  Bangalore    Student                2.0
#
#         Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# User 1            5.0   9.0                 2.0                 0
# User 2            2.0   5.9                 4.0                 0
#
#        Sleep Duration Dietary Habits    Degree Suicidal Thoughts  \
# User 1      7-8 Hours        Healthy       BSc               Yes
# User 2      5-6 hours       Moderate  Class 12                No
#
#         Work/Study Hours  Financial Stress Family History of Mental Illness
# User 1               3.0               1.0                              Yes
# User 2               3.0               2.0                               No

# %%
# Inference
loaded_model.predict(df_users)
loaded_model.predict_proba(df_users)
# Out:
# array([[0.40070811, 0.59929189],
#        [0.98831654, 0.01168346]])

# %% [markdown]
# User 1 terprediksi sedang mengalami depresi, sedangkan User 2 terprediksi sedang tidak mengalami depresi
